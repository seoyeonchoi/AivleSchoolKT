# %%
# aivle 5405
# -*- coding: utf-8 -*-

import sys

a = int(input())
a_sum = 0
a_reverse = 0

for i in range(1, len(str(a))+1):
    if a%10:
        a_sum += (a%10)    
    a_reverse += (a%10)*((10**(len(str(a))-1)))
    a//=10

print(a_reverse)
print(a_sum)
# Out:
# 200
# 2
# 2

# %%
# 5406

# -*- coding: utf-8 -*-
import sys

# a = int(sys.stdin.readline())
a = int(input())

for i in range(1, a+1):
    num = i
    for _ in range(a):
        print(num, end=' ')
        num = num + a
    print('')
# Out:
# 3
# 147
# 258
# 369

# %%
# 5408

a, b = input().split()

new_a = int(a[0]) + int(a[1])*10 + int(a[2])*100
new_b = int(b[0]) + int(b[1])*10 + int(b[2])*100

print(new_a if new_a > new_b else new_b)
# Out:
# 452 486
# 684

# %%
# 5411

import sys

# a = int(sys.stdin.readline())
a = int(input())

for i in range(1, a+1):
    print('*'*i)
# Out:
# 3
# *
# **
# ***

# %%
# 5409

a = int(input())

if a>=90:
    print('A')
elif a>= 80:
    print('B')
elif a>= 70:
    print('C')
else:
    print('F')
# Out:
# 98
# A

# %%
# 5412

a = input()
print(a.count('k'))
# Out:
# nanum
# 0

# %%
# 5410

a = input()
b = input()
print(a)
print(b)
# Out:
# hello
# olleh
# hello
# olleh

# %%
# 5413
a = int(input())
print('O' if a%2 else 'E')
# Out:
# 3
# O

# %%
# 5415
import sys
a = int(sys.stdin.readline())
print(a//5)

# %%
# 5414

# a, b, c = map(int, input().split())
a,b,c = map(int,sys.stdin.readline().split())
if b-a > c-b:
    ans = b-a-1
else:
    ans = c-b-1
    
print(ans)
# Out:
# 23 54 232
# 177

# %%
# 5416

import sys

a = int(sys.stdin.readline())
num_list = []
for i in range(a):
    b = int(sys.stdin.readline())
    num_list.append(b)

print(sum(num_list))

# %%
# 5420 

# a = int(sys.stdin.readline())
a = int(input())
print(a*a*3.14 if str(a*a*3.14)[-1] != '0' else int(a*a*3.14))
# Out:
# 5
# 78.5
# 5

# %%
# 5417

# a = int(sys.stdin.readline())
a = int(input())
count = []

for i in range(2, a+1):
    flag = 0 # 소수 여부 판별 (소수면 0 아니면 1)
    for k in range(2, i):
        if i % k == 0:
            flag = 1
            break
    
    if (flag == 0):
        print(i)
        count.append(i)

print(len(count))
# Out:
# 10
# 2
# 3
# 5
# 7
# 4

# %%
# 5421

print(a//16)

# %%
#5418

a = input()
print(0 if len(a)>=20 else -1)
# Out:
# kimnaraesarangbadahaneul
# 0

# %%
#5422
print(a%3)

# %%
# 5424
stage = int(input())
# H = list(map(int,sys.stdin.readline().split()))
H = list(map(int, input()))

for h in H:
    if h < 160:
        ans = 'I'
        height = h
        break

if ans == 'I':
    print(ans, height)
else:
    print('P')
# Out:
# 3
# 170 180 100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-34650eea3384> in <module>
#       2 stage = int(input())
#       3 # H = list(map(int,sys.stdin.readline().split()))
# ----> 4 H = list(map(int, input()))
#       5
#       6 for h in H:
#
# ValueError: invalid literal for int() with base 10: ' '
